# %% [markdown]
# <a href="https://colab.research.google.com/github/mohameddosama22/my-first-repo/blob/main/Deep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# استدعاء المكتبات الأساسية

import numpy as np
import matplotlib.pyplot as plt

# تحميل Dataset MNIST
from tensorflow.keras.datasets import mnist

# %%
# تحميل البيانات

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (60000, 28, 28)
# (60000,)

# %%
plt.imshow(x_train[5], cmap='gray')
plt.show()

# %%
print(y_train[5])
# Out:
# 2

# %%
# تحويل القيم من 0-255 إلى 0-1

x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
model = Sequential([

    Flatten(input_shape=(28,28)),

    Dense(128, activation='relu'),

    Dense(10, activation='softmax')

])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(

    optimizer='adam',

    loss='sparse_categorical_crossentropy',

    metrics=['accuracy']

)

# %%
history = model.fit(

    x_train,
    y_train,

    epochs=5

)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9254 - loss: 0.2608
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9661 - loss: 0.1155
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9768 - loss: 0.0772
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9825 - loss: 0.0573
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9861 - loss: 0.0442

# %%
test_loss, test_accuracy = model.evaluate(

    x_test,
    y_test

)

print("Accuracy =", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9787 - loss: 0.0721
# Accuracy = 0.9786999821662903
